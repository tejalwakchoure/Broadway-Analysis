# %%
import requests
import time
import re
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from urllib.request import urlopen
from urllib.parse import quote
from bs4 import BeautifulSoup
pd.options.mode.chained_assignment = None

# %%
url = "https://www.ibdb.com/shows/#current"
soup = BeautifulSoup(urlopen(url), 'html.parser')
showlinks = soup.find("div", {"id": "current"}).find_all("a", href=re.compile("/broadway-production/"))
shows = pd.DataFrame()
for showlink in showlinks:
    shows = pd.concat([shows, pd.DataFrame([[showlink.find("i").text, "https://www.ibdb.com/"+quote(showlink['href'])+"#OpeningNightCast"]])], ignore_index=True)
shows.columns = ["show","IBDB page"]
shows
# Out:
#                                                  show  \
# 0                                            & Juliet
# 1         A Beautiful Noise, The Neil Diamond Musical
# 2                                             Aladdin
# 3                                             Camelot
# 4                                             Chicago
# 5                                             Fat Ham
# 6                                          Funny Girl
# 7                                   Good Night, Oscar
# 8                                          Grey House
# 9                                           Hadestown
# 10                                           Hamilton
# 11  Harry Potter and the Cursed Child, Parts One a...
# 12                                     Here Lies Love
# 13                                    Kimberly Akimbo
# 14                                       Leopoldstadt
# 15                                         Life of Pi
# 16                                     MJ The Musical
# 17                          Moulin Rouge! The Musical
# 18                                 New York, New York
# 19                          Once Upon a One More Time
# 20                                             Parade
# 21                               Peter Pan Goes Wrong
# 22                                        Prima Facie
# 23                                            Shucked
# 24                                                Six
# 25                                   Some Like It Hot
# 26                                       Sweeney Todd
# 27                                 The Book of Mormon
# 28                                      The Lion King
# 29               The Sign in Sidney Brustein's Window
# 30                                             Wicked
#
#                                             IBDB page
# 0   https://www.ibdb.com//broadway-production/-jul...
# 1   https://www.ibdb.com//broadway-production/a-be...
# 2   https://www.ibdb.com//broadway-production/alad...
# 3   https://www.ibdb.com//broadway-production/came...
# 4   https://www.ibdb.com//broadway-production/chic...
# 5   https://www.ibdb.com//broadway-production/fat-...
# 6   https://www.ibdb.com//broadway-production/funn...
# 7   https://www.ibdb.com//broadway-production/good...
# 8   https://www.ibdb.com//broadway-production/grey...
# 9   https://www.ibdb.com//broadway-production/hade...
# 10  https://www.ibdb.com//broadway-production/hami...
# 11  https://www.ibdb.com//broadway-production/harr...
# 12  https://www.ibdb.com//broadway-production/here...
# 13  https://www.ibdb.com//broadway-production/kimb...
# 14  https://www.ibdb.com//broadway-production/leop...
# 15  https://www.ibdb.com//broadway-production/life...
# 16  https://www.ibdb.com//broadway-production/mj-t...
# 17  https://www.ibdb.com//broadway-production/moul...
# 18  https://www.ibdb.com//broadway-production/new-...
# 19  https://www.ibdb.com//broadway-production/once...
# 20  https://www.ibdb.com//broadway-production/para...
# 21  https://www.ibdb.com//broadway-production/pete...
# 22  https://www.ibdb.com//broadway-production/prim...
# 23  https://www.ibdb.com//broadway-production/shuc...
# 24  https://www.ibdb.com//broadway-production/six-...
# 25  https://www.ibdb.com//broadway-production/some...
# 26  https://www.ibdb.com//broadway-production/swee...
# 27  https://www.ibdb.com//broadway-production/the-...
# 28  https://www.ibdb.com//broadway-production/the-...
# 29  https://www.ibdb.com//broadway-production/the-...
# 30  https://www.ibdb.com//broadway-production/wick...

# %%
shows.to_csv("shows_with_opening_nights.csv")

# %%
# get all performers
def getperformers(show, page):
    soup=BeautifulSoup(urlopen(page),"html.parser")
    cast = soup.find("div", {"id": "OpeningNightCast"})
    if cast == None:
        return pd.DataFrame(["",""])

    castlinks = cast.find_all("a", href=re.compile("/broadway-cast-staff/"))
    names = set(i.get_text() for i in castlinks)
    performersdf = pd.DataFrame([name, show] for name in names)
    return performersdf
    
performers = pd.concat([getperformers(x, y) for x, y in zip(shows['show'], shows['IBDB page'])], ignore_index=True)
performers.columns = ["actor","show"]
performers.head()
# Out:
#                actor      show
# 0       Joomin Hwang  & Juliet
# 1  Alaina Vi Maderal  & Juliet
# 2        Betsy Wolfe  & Juliet
# 3         Megan Kane  & Juliet
# 4      Virgil Gadson  & Juliet

# %%
performers
# Out:
#                  actor      show
# 0         Joomin Hwang  & Juliet
# 1    Alaina Vi Maderal  & Juliet
# 2          Betsy Wolfe  & Juliet
# 3           Megan Kane  & Juliet
# 4        Virgil Gadson  & Juliet
# ..                 ...       ...
# 778       Melissa Fahn    Wicked
# 779   Corinne McFadden    Wicked
# 780       Kisha Howard    Wicked
# 781  Kristin Chenoweth    Wicked
# 782   Derrick Williams    Wicked
#
# [783 rows x 2 columns]

# %%
def getwikipedias(name):
    subject = quote(name.replace(" ", "_").replace(".",""))
    link = 'https://en.wikipedia.org/wiki/'+subject

    if requests.get(link).status_code != 200:
        return ""

    summary = requests.get("https://en.wikipedia.org/api/rest_v1/page/summary/"+subject).json()['extract']
    if any([x in summary for x in ["actor", "actress"]]):
        return link
    else:
        return ""

performers['wikipedia link'] = performers['actor'].apply(lambda x: getwikipedias(x))
performers.head()
# Out:
#                actor      show                             wikipedia link
# 0       Joomin Hwang  & Juliet
# 1  Alaina Vi Maderal  & Juliet
# 2        Betsy Wolfe  & Juliet  https://en.wikipedia.org/wiki/Betsy_Wolfe
# 3         Megan Kane  & Juliet
# 4      Virgil Gadson  & Juliet

# %%
performers.shape
# Out:
# (783, 3)

# %%
performers.to_csv("performer_list.csv")

# %%
perf = performers

def getdetails(link, taglist):
    if requests.get(link).status_code != 200:
        return ""

    soup = BeautifulSoup(urlopen(link),"html.parser")
    infobox = soup.find("table", class_="infobox")

    if infobox == None:
        return ""
    
    info = {}
    for th, td in zip(infobox.select('th.infobox-label'), infobox.select('td.infobox-data')):
        info[th.text.replace("\xa0"," ")] = td.text.replace("\xa0"," ")

    for key in info.keys():
        if key.lower() in taglist:
            return(info[key])
            
    return ""

schooltags = ['education', 'alma mater', 'school']
parenttags = ['parents']
relativestags = ['relatives']

perf['school'] = perf['wikipedia link'].apply(lambda x: getdetails(x, schooltags) if x!="" else "")
perf['parents'] = perf['wikipedia link'].apply(lambda x: getdetails(x, parenttags) if x!="" else "")
perf['relatives'] = perf['wikipedia link'].apply(lambda x: getdetails(x, relativestags) if x!="" else "")

perf
# Out:
#                  actor      show  \
# 0         Joomin Hwang  & Juliet
# 1    Alaina Vi Maderal  & Juliet
# 2          Betsy Wolfe  & Juliet
# 3           Megan Kane  & Juliet
# 4        Virgil Gadson  & Juliet
# ..                 ...       ...
# 778       Melissa Fahn    Wicked
# 779   Corinne McFadden    Wicked
# 780       Kisha Howard    Wicked
# 781  Kristin Chenoweth    Wicked
# 782   Derrick Williams    Wicked
#
#                                       wikipedia link  \
# 0
# 1
# 2          https://en.wikipedia.org/wiki/Betsy_Wolfe
# 3
# 4
# ..                                               ...
# 778       https://en.wikipedia.org/wiki/Melissa_Fahn
# 779
# 780
# 781  https://en.wikipedia.org/wiki/Kristin_Chenoweth
# 782
#
#                                            school parents relatives
# 0
# 1
# 2                  University of Cincinnati (BFA)
# 3
# 4
# ..                                            ...     ...       ...
# 778  California State University at Long Beach[3]
# 779
# 780
# 781
# 782
#
# [783 rows x 6 columns]

# %%
def getcredits(link, credittags):
    if requests.get(link).status_code != 200:
        return ""

    sections = requests.get("https://en.wikipedia.org/api/rest_v1/page/mobile-sections-remaining/"+link.split("/")[-1]).json()['sections']
    for section in sections:
        if section['line'].lower().split(" ")[0] in credittags and "<table" in section['text']:
            table = BeautifulSoup(section['text'], "html.parser").find("table")
            return len(table.find_all("i"))

            # v = []
            # for tr in soup.find_all("tr")[1:]:
            #     # print(tr)
            #     # for td in tr.find_all('td'):
            #     row = [i.text for i in tr]
            #     print(row)
            #     print("_________")
            #     v.append(row)
            # print(len(v))
            # df = pd.DataFrame(v)
    return ""

filmtags = ["film"]
tvtags = ["television"]
theatretags = ["theatre","theater","stage"]

perf['film credits'] = perf['wikipedia link'].apply(lambda x: getcredits(x, filmtags) if x!="" else "")
perf['tv credits'] = perf['wikipedia link'].apply(lambda x: getcredits(x, tvtags) if x!="" else "")
perf['theater credits'] = perf['wikipedia link'].apply(lambda x: getcredits(x, theatretags) if x!="" else "")

perf
# Out:
#                  actor      show  \
# 0         Joomin Hwang  & Juliet
# 1    Alaina Vi Maderal  & Juliet
# 2          Betsy Wolfe  & Juliet
# 3           Megan Kane  & Juliet
# 4        Virgil Gadson  & Juliet
# ..                 ...       ...
# 778       Melissa Fahn    Wicked
# 779   Corinne McFadden    Wicked
# 780       Kisha Howard    Wicked
# 781  Kristin Chenoweth    Wicked
# 782   Derrick Williams    Wicked
#
#                                       wikipedia link  \
# 0
# 1
# 2          https://en.wikipedia.org/wiki/Betsy_Wolfe
# 3
# 4
# ..                                               ...
# 778       https://en.wikipedia.org/wiki/Melissa_Fahn
# 779
# 780
# 781  https://en.wikipedia.org/wiki/Kristin_Chenoweth
# 782
#
#                                            school parents relatives  \
# 0
# 1
# 2                  University of Cincinnati (BFA)
# 3
# 4
# ..                                            ...     ...       ...
# 778  California State University at Long Beach[3]
# 779
# 780
# 781
# 782
#
#     film credits tv credits theater credits
# 0
# 1
# 2              4          2              22
# 3
# 4
# ..           ...        ...             ...
# 778            2                          1
# 779
# 780
# 781           31         45
# 782
#
# [783 rows x 9 columns]

# %%
perf.to_csv("performer_details.csv")

# %%
# # !pip install plotly
# import plotly.express as px
# school_data = perf[perf.school!=""].school.value_counts()
# fig = px.scatter(school_data)
# fig.write_html("schools.html")
# fig.show()

# %%
shows = pd.read_csv("shows.csv")
# shows['opening year'] =
# Out:
#     Unnamed: 0                                               show  \
# 0            0                                           & Juliet
# 1            1        A Beautiful Noise, The Neil Diamond Musical
# 2            2                                            Aladdin
# 3            3                                            Camelot
# 4            4                                            Chicago
# 5            5                                            Fat Ham
# 6            6                                         Funny Girl
# 7            7                                  Good Night, Oscar
# 8            8                                         Grey House
# 9            9                                          Hadestown
# 10          10                                           Hamilton
# 11          11  Harry Potter and the Cursed Child, Parts One a...
# 12          12                                     Here Lies Love
# 13          13                                    Kimberly Akimbo
# 14          14                                       Leopoldstadt
# 15          15                                         Life of Pi
# 16          16                                     MJ The Musical
# 17          17                          Moulin Rouge! The Musical
# 18          18                                 New York, New York
# 19          19                          Once Upon a One More Time
# 20          20                                             Parade
# 21          21                               Peter Pan Goes Wrong
# 22          22                                        Prima Facie
# 23          23                                            Shucked
# 24          24                                                Six
# 25          25                                   Some Like It Hot
# 26          26                                       Sweeney Todd
# 27          27                                 The Book of Mormon
# 28          28                                      The Lion King
# 29          29               The Sign in Sidney Brustein's Window
# 30          30                                             Wicked
#
#                                             IBDB page
# 0   https://www.ibdb.com//broadway-production/-jul...
# 1   https://www.ibdb.com//broadway-production/a-be...
# 2   https://www.ibdb.com//broadway-production/alad...
# 3   https://www.ibdb.com//broadway-production/came...
# 4   https://www.ibdb.com//broadway-production/chic...
# 5   https://www.ibdb.com//broadway-production/fat-...
# 6   https://www.ibdb.com//broadway-production/funn...
# 7   https://www.ibdb.com//broadway-production/good...
# 8   https://www.ibdb.com//broadway-production/grey...
# 9   https://www.ibdb.com//broadway-production/hade...
# 10  https://www.ibdb.com//broadway-production/hami...
# 11  https://www.ibdb.com//broadway-production/harr...
# 12  https://www.ibdb.com//broadway-production/here...
# 13  https://www.ibdb.com//broadway-production/kimb...
# 14  https://www.ibdb.com//broadway-production/leop...
# 15  https://www.ibdb.com//broadway-production/life...
# 16  https://www.ibdb.com//broadway-production/mj-t...
# 17  https://www.ibdb.com//broadway-production/moul...
# 18  https://www.ibdb.com//broadway-production/new-...
# 19  https://www.ibdb.com//broadway-production/once...
# 20  https://www.ibdb.com//broadway-production/para...
# 21  https://www.ibdb.com//broadway-production/pete...
# 22  https://www.ibdb.com//broadway-production/prim...
# 23  https://www.ibdb.com//broadway-production/shuc...
# 24  https://www.ibdb.com//broadway-production/six-...
# 25  https://www.ibdb.com//broadway-production/some...
# 26  https://www.ibdb.com//broadway-production/swee...
# 27  https://www.ibdb.com//broadway-production/the-...
# 28  https://www.ibdb.com//broadway-production/the-...
# 29  https://www.ibdb.com//broadway-production/the-...
# 30  https://www.ibdb.com//broadway-production/wick...

# %%
def getopeningyear(page):
    soup = BeautifulSoup(urlopen(page), 'html.parser')
    txt = soup.find("div", class_="production-info-panel").find("div", class_="xt-info-block").find_all("div", class_="col")

    for i in txt:
        if "Opening Date".lower() in i.get_text().lower():
            return i.select("div.xt-main-title")[0].text.split(',')[-1]

shows['opening night'] = shows['IBDB page'].apply(lambda x: getopeningyear(x) if x!="" else "")
# shows.drop(["Unnamed: 0"], axis=1)

shows


# import lxml.html
# dom = lxml.html.fromstring(requests.get(page).content)
# dom.cssselect(".production-info-panel")[0].text_content().strip()
# Out:
#     Unnamed: 0                                               show  \
# 0            0                                           & Juliet
# 1            1        A Beautiful Noise, The Neil Diamond Musical
# 2            2                                            Aladdin
# 3            3                                            Camelot
# 4            4                                            Chicago
# 5            5                                            Fat Ham
# 6            6                                         Funny Girl
# 7            7                                  Good Night, Oscar
# 8            8                                         Grey House
# 9            9                                          Hadestown
# 10          10                                           Hamilton
# 11          11  Harry Potter and the Cursed Child, Parts One a...
# 12          12                                     Here Lies Love
# 13          13                                    Kimberly Akimbo
# 14          14                                       Leopoldstadt
# 15          15                                         Life of Pi
# 16          16                                     MJ The Musical
# 17          17                          Moulin Rouge! The Musical
# 18          18                                 New York, New York
# 19          19                          Once Upon a One More Time
# 20          20                                             Parade
# 21          21                               Peter Pan Goes Wrong
# 22          22                                        Prima Facie
# 23          23                                            Shucked
# 24          24                                                Six
# 25          25                                   Some Like It Hot
# 26          26                                       Sweeney Todd
# 27          27                                 The Book of Mormon
# 28          28                                      The Lion King
# 29          29               The Sign in Sidney Brustein's Window
# 30          30                                             Wicked
#
#                                             IBDB page opening night
# 0   https://www.ibdb.com//broadway-production/-jul...          2022
# 1   https://www.ibdb.com//broadway-production/a-be...          2022
# 2   https://www.ibdb.com//broadway-production/alad...          2014
# 3   https://www.ibdb.com//broadway-production/came...          2023
# 4   https://www.ibdb.com//broadway-production/chic...          1996
# 5   https://www.ibdb.com//broadway-production/fat-...          2023
# 6   https://www.ibdb.com//broadway-production/funn...          2022
# 7   https://www.ibdb.com//broadway-production/good...          2023
# 8   https://www.ibdb.com//broadway-production/grey...          2023
# 9   https://www.ibdb.com//broadway-production/hade...          2019
# 10  https://www.ibdb.com//broadway-production/hami...          2015
# 11  https://www.ibdb.com//broadway-production/harr...          2018
# 12  https://www.ibdb.com//broadway-production/here...          2023
# 13  https://www.ibdb.com//broadway-production/kimb...          2022
# 14  https://www.ibdb.com//broadway-production/leop...          2022
# 15  https://www.ibdb.com//broadway-production/life...          2023
# 16  https://www.ibdb.com//broadway-production/mj-t...          2022
# 17  https://www.ibdb.com//broadway-production/moul...          2019
# 18  https://www.ibdb.com//broadway-production/new-...          2023
# 19  https://www.ibdb.com//broadway-production/once...          2023
# 20  https://www.ibdb.com//broadway-production/para...          2023
# 21  https://www.ibdb.com//broadway-production/pete...          2023
# 22  https://www.ibdb.com//broadway-production/prim...          2023
# 23  https://www.ibdb.com//broadway-production/shuc...          2023
# 24  https://www.ibdb.com//broadway-production/six-...          2021
# 25  https://www.ibdb.com//broadway-production/some...          2022
# 26  https://www.ibdb.com//broadway-production/swee...          2023
# 27  https://www.ibdb.com//broadway-production/the-...          2011
# 28  https://www.ibdb.com//broadway-production/the-...          1997
# 29  https://www.ibdb.com//broadway-production/the-...          2023
# 30  https://www.ibdb.com//broadway-production/wick...          2003

# %%
perf = pd.read_csv("performer_details.csv")
mergeddf = pd.merge(shows, perf, on="show").drop(["Unnamed: 0_x", "Unnamed: 0_y"], axis=1)

# %%
screencredittags = ['film', 'television', 'filmography']

def getscreencreditsbefore(link, year):
    if type(link)!=str or requests.get(link).status_code != 200:
        return ""

    counter = 0
    sections = requests.get("https://en.wikipedia.org/api/rest_v1/page/mobile-sections-remaining/"+link.split("/")[-1]).json()['sections']
    for section in sections:
        if section['line'].lower().split(" ")[0] in screencredittags and "<table" in section['text']:
            table = BeautifulSoup(section['text'], "html.parser").find("table")
            for tr in table.find_all("tr"):
                td = tr.find("td")
                if td:
                    showyr = td.text.split('-')[0]
                    if showyr.isdigit() and int(showyr) < int(year):
                        counter+=1
            # l = []
            # for tr in table.find_all("tr"):
            #     td = tr.find_all('td')
            #     row = [tr.text for tr in td]
            #     l.append(row[0:2])
            # print(pd.DataFrame(l, columns=["year", "name"]))
    return counter


def getscreencreditsafter(link, year):
    if type(link)!=str or requests.get(link).status_code != 200:
        return ""

    counter = 0
    sections = requests.get("https://en.wikipedia.org/api/rest_v1/page/mobile-sections-remaining/"+link.split("/")[-1]).json()['sections']
    for section in sections:
        if section['line'].lower().split(" ")[0] in screencredittags and "<table" in section['text']:
            table = BeautifulSoup(section['text'], "html.parser").find("table")
            for tr in table.find_all("tr"):
                td = tr.find("td")
                if td:
                    showyr = td.text.split('-')[0]
                    if showyr.isdigit() and int(showyr) > int(year):
                        counter+=1

    return counter

# mergeddf['screen credits before opening night'] = 
# mergeddf.apply(lambda x: getscreencreditsbefore(x['wikipedia link'], x['opening night']), axis=1)
mergeddf['screen credits before opening night'] = mergeddf.apply(lambda x: getscreencreditsbefore(x['wikipedia link'], x['opening night']), axis=1)
mergeddf['screen credits after opening night'] = mergeddf.apply(lambda x: getscreencreditsafter(x['wikipedia link'], x['opening night']), axis=1)

# %%
mergeddf
# mergeddf.to_csv("performer_details_with_timed_credits.csv")
# Out:
#          show                                          IBDB page  \
# 0    & Juliet  https://www.ibdb.com//broadway-production/-jul...
# 1    & Juliet  https://www.ibdb.com//broadway-production/-jul...
# 2    & Juliet  https://www.ibdb.com//broadway-production/-jul...
# 3    & Juliet  https://www.ibdb.com//broadway-production/-jul...
# 4    & Juliet  https://www.ibdb.com//broadway-production/-jul...
# ..        ...                                                ...
# 778    Wicked  https://www.ibdb.com//broadway-production/wick...
# 779    Wicked  https://www.ibdb.com//broadway-production/wick...
# 780    Wicked  https://www.ibdb.com//broadway-production/wick...
# 781    Wicked  https://www.ibdb.com//broadway-production/wick...
# 782    Wicked  https://www.ibdb.com//broadway-production/wick...
#
#     opening night              actor  \
# 0            2022       Joomin Hwang
# 1            2022  Alaina Vi Maderal
# 2            2022        Betsy Wolfe
# 3            2022         Megan Kane
# 4            2022      Virgil Gadson
# ..            ...                ...
# 778          2003       Melissa Fahn
# 779          2003   Corinne McFadden
# 780          2003       Kisha Howard
# 781          2003  Kristin Chenoweth
# 782          2003   Derrick Williams
#
#                                       wikipedia link  \
# 0                                                NaN
# 1                                                NaN
# 2          https://en.wikipedia.org/wiki/Betsy_Wolfe
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 778       https://en.wikipedia.org/wiki/Melissa_Fahn
# 779                                              NaN
# 780                                              NaN
# 781  https://en.wikipedia.org/wiki/Kristin_Chenoweth
# 782                                              NaN
#
#                                            school parents relatives  \
# 0                                             NaN     NaN       NaN
# 1                                             NaN     NaN       NaN
# 2                  University of Cincinnati (BFA)     NaN       NaN
# 3                                             NaN     NaN       NaN
# 4                                             NaN     NaN       NaN
# ..                                            ...     ...       ...
# 778  California State University at Long Beach[3]     NaN       NaN
# 779                                           NaN     NaN       NaN
# 780                                           NaN     NaN       NaN
# 781                                           NaN     NaN       NaN
# 782                                           NaN     NaN       NaN
#
#      film credits  tv credits  theater credits  \
# 0             NaN         NaN              NaN
# 1             NaN         NaN              NaN
# 2             4.0         2.0             22.0
# 3             NaN         NaN              NaN
# 4             NaN         NaN              NaN
# ..            ...         ...              ...
# 778           2.0         NaN              1.0
# 779           NaN         NaN              NaN
# 780           NaN         NaN              NaN
# 781          31.0        45.0              NaN
# 782           NaN         NaN              NaN
#
#     screen credits before opening night screen credits after opening night
# 0
# 1
# 2                                     7                                  0
# 3
# 4
# ..                                  ...                                ...
# 778                                   4                                 10
# 779
# 780
# 781                                   4                                 28
# 782
#
# [783 rows x 13 columns]

# %%
perf_details = pd.read_csv("performer_EDA.csv")
perf_details
# Out:
#                      actor                       show  \
# 0            Anthony Ramos                   Hamilton
# 1              Colton Ryan         New York, New York
# 2     Jasmine Cephas Jones                   Hamilton
# 3          Jennifer Simard  Once Upon a One More Time
# 4              Myles Frost             MJ The Musical
# ..                     ...                        ...
# 762          Winsome Brown                 Grey House
# 763          Wonza Johnson             MJ The Musical
# 764      Yurel Echezarreta                    Aladdin
# 765  Yvette Gonzalez-Nacer                  Hadestown
# 766         Zelig Williams             MJ The Musical
#
#                                         wikipedia link  \
# 0          https://en.wikipedia.org/wiki/Anthony_Ramos
# 1            https://en.wikipedia.org/wiki/Colton_Ryan
# 2    https://en.wikipedia.org/wiki/Jasmine_Cephas_J...
# 3        https://en.wikipedia.org/wiki/Jennifer_Simard
# 4            https://en.wikipedia.org/wiki/Myles_Frost
# ..                                                 ...
# 762                                                NaN
# 763                                                NaN
# 764                                                NaN
# 765                                                NaN
# 766                                                NaN
#
#                            terminal school          school (2)  \
# 0    American Musical and Dramatic Academy                 NaN
# 1               Baldwin Wallace University                 NaN
# 2                 Berklee College of Music                 NaN
# 3                      Boston Conservatory                 NaN
# 4                   Bowie State University  Belmont University
# ..                                     ...                 ...
# 762                                    NaN                 NaN
# 763                                    NaN                 NaN
# 764                                    NaN                 NaN
# 765                                    NaN                 NaN
# 766                                    NaN                 NaN
#
#                                              relatives  film credits  \
# 0                                                  NaN           0.0
# 1                                                  NaN           4.0
# 2    Ron Cephas Jones (father)\nKim Lesley Hartman ...          12.0
# 3                                                  NaN           6.0
# 4                                                  NaN           1.0
# ..                                                 ...           ...
# 762                                                NaN           NaN
# 763                                                NaN           NaN
# 764                                                NaN           NaN
# 765                                                NaN           NaN
# 766                                                NaN           NaN
#
#      tv credits  theater credits
# 0           8.0              9.0
# 1           6.0              8.0
# 2           8.0              3.0
# 3           6.0             11.0
# 4           4.0              NaN
# ..          ...              ...
# 762         NaN              NaN
# 763         NaN              NaN
# 764         NaN              NaN
# 765         NaN              NaN
# 766         NaN              NaN
#
# [767 rows x 9 columns]

# %%
mergeddf_t = mergeddf[["actor", "show", "opening night", "screen credits before opening night", "screen credits after opening night"]]
perf_details_t = perf_details.drop_duplicates()
final_perf_details = pd.merge(perf_details, mergeddf_t, on=["actor", "show"])

final_perf_details.to_csv("final_perf_details.csv")
